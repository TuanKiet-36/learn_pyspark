# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import array,struct,lit,udf,concat,col
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
from pyspark.sql.functions import avg, round,sum,max,min
spark = SparkSession.builder.appName("TuanKiet").getOrCreate()
sc = spark.sparkContext
salaries_df = spark.read.csv("salaries.csv", header=True, inferSchema=True)

# %%
data = sc.parallelize([(1,'mahher',500,1000),
        (2,'wafa',4000,1000),
        (3,'kita',5000,1000),
        (4,'kuta',500,1000)])
schema = StructType([StructField("age",IntegerType()),
                     StructField("education_num",StringType(),nullable=False),
                     StructField("marital_status",IntegerType()),
                     StructField("occupation",IntegerType())
                    ])
df = spark.createDataFrame(data=data,schema=schema)
salaries_df.show(5)
# Out:
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+
# |work_year|experience_level|employment_type|           job_title|salary|salary_currency|salary_in_usd|employee_residence|remote_ratio|company_location|company_size|scores|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+
# |     2020|              EN|             FT| Azure Data Engineer|100000|            USD|       100000|                MU|           0|              MU|           S|     0|
# |     2020|              EN|             CT|  Staff Data Analyst| 60000|            CAD|        44753|                CA|          50|              CA|           L|     0|
# |     2020|              SE|             FT|Staff Data Scientist|164000|            USD|       164000|                US|          50|              US|           M|     0|
# |     2020|              EN|             FT|        Data Analyst| 42000|            EUR|        47899|                DE|           0|              DE|           L|     0|
# |     2020|              EX|             FT|      Data Scientist|300000|            USD|       300000|                US|         100|              US|           L|     0|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+
# only showing top 5 rows

# %% [markdown]
# # groupBy

# %%
CA_jobs = salaries_df.where(salaries_df['company_location'] == "CA").where(salaries_df['experience_level']== "EN").groupBy().avg("salary_in_usd")
CA_jobs.show()
# Out:
# +------------------+
# |avg(salary_in_usd)|
# +------------------+
# | 97330.53932584269|
# +------------------+

# %%
(
    salaries_df
        .where(salaries_df['remote_ratio'] >= 50)
        .groupBy('company_location')
        .agg(round(min('remote_ratio'), 0).alias('avg_remote_ratio'))
        .show(5)
)
# Out:
# +----------------+----------------+
# |company_location|avg_remote_ratio|
# +----------------+----------------+
# |              DZ|              50|
# |              FI|              50|
# |              UA|              50|
# |              RO|              50|
# |              NL|              50|
# +----------------+----------------+
# only showing top 5 rows

# %% [markdown]
# # Udf

# %%
def plusOne(x):
    return x + 1
plusOne_udf = udf(plusOne,IntegerType())
salaries_df.withColumn('TEST',plusOne_udf(col('remote_ratio'))).show(5)
# Out:
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+----+
# |work_year|experience_level|employment_type|           job_title|salary|salary_currency|salary_in_usd|employee_residence|remote_ratio|company_location|company_size|scores|TEST|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+----+
# |     2020|              EN|             FT| Azure Data Engineer|100000|            USD|       100000|                MU|           0|              MU|           S|     0|   1|
# |     2020|              EN|             CT|  Staff Data Analyst| 60000|            CAD|        44753|                CA|          50|              CA|           L|     0|  51|
# |     2020|              SE|             FT|Staff Data Scientist|164000|            USD|       164000|                US|          50|              US|           M|     0|  51|
# |     2020|              EN|             FT|        Data Analyst| 42000|            EUR|        47899|                DE|           0|              DE|           L|     0|   1|
# |     2020|              EX|             FT|      Data Scientist|300000|            USD|       300000|                US|         100|              US|           L|     0| 101|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+----+
# only showing top 5 rows

# %%
schema = StructType([StructField("age",IntegerType()),
                     StructField("education_num",IntegerType(),nullable=False),
                     StructField("marital_status",StringType()),
                     StructField("occupation",StringType()),
                     StructField("income",StringType()),
                    ])
census_adult = spark.read.csv("salaries.csv", sep=',', header=True, schema=schema)
census_adult.show(5)
# Out:
# +----+-------------+--------------+--------------------+------+
# | age|education_num|marital_status|          occupation|income|
# +----+-------------+--------------+--------------------+------+
# |2020|         NULL|            FT| Azure Data Engineer|100000|
# |2020|         NULL|            CT|  Staff Data Analyst| 60000|
# |2020|         NULL|            FT|Staff Data Scientist|164000|
# |2020|         NULL|            FT|        Data Analyst| 42000|
# |2020|         NULL|            FT|      Data Scientist|300000|
# +----+-------------+--------------+--------------------+------+
# only showing top 5 rows

# %%
census_adult.drop('education_num').show()
# Out:
# +----+--------------+--------------------+------+
# | age|marital_status|          occupation|income|
# +----+--------------+--------------------+------+
# |2020|            FT| Azure Data Engineer|100000|
# |2020|            CT|  Staff Data Analyst| 60000|
# |2020|            FT|Staff Data Scientist|164000|
# |2020|            FT|        Data Analyst| 42000|
# |2020|            FT|      Data Scientist|300000|
# |2020|            CT|  Sales Data Analyst| 60000|
# |2020|            FT|  Staff Data Analyst| 15000|
# |2020|            FT|Business Data Ana...| 95000|
# |2020|            FT|        Data Analyst| 20000|
# |2020|            FT|      Data Scientist| 43200|
# |2020|            FT|Machine Learning ...|157000|
# |2020|            FT|       Data Engineer| 48000|
# |2020|            FT|Product Data Analyst| 20000|
# |2020|            FT|       Data Engineer| 51999|
# |2020|            FT|   Big Data Engineer| 70000|
# |2020|            FT|      Data Scientist| 60000|
# |2020|            FT|  Research Scientist|450000|
# |2020|            FT|        Data Analyst| 41000|
# |2020|            FT|       Data Engineer| 65000|
# |2020|            FT|      Data Scientist|103000|
# +----+--------------+--------------------+------+
# only showing top 20 rows

# %%
census_adult.createOrReplaceTempView('census')
result = spark.sql("SELECT age,occupation FROM census")
result.show()
# Out:
# +----+--------------------+
# | age|          occupation|
# +----+--------------------+
# |2020| Azure Data Engineer|
# |2020|  Staff Data Analyst|
# |2020|Staff Data Scientist|
# |2020|        Data Analyst|
# |2020|      Data Scientist|
# |2020|  Sales Data Analyst|
# |2020|  Staff Data Analyst|
# |2020|Business Data Ana...|
# |2020|        Data Analyst|
# |2020|      Data Scientist|
# |2020|Machine Learning ...|
# |2020|       Data Engineer|
# |2020|Product Data Analyst|
# |2020|       Data Engineer|
# |2020|   Big Data Engineer|
# |2020|      Data Scientist|
# |2020|  Research Scientist|
# |2020|        Data Analyst|
# |2020|       Data Engineer|
# |2020|      Data Scientist|
# +----+--------------------+
# only showing top 20 rows

# %%
result.withColumn('bonus',result.occupation*0.1).show()
# Out:
# +---+----------+-----+
# |age|occupation|bonus|
# +---+----------+-----+
# |  1|      1000|100.0|
# |  2|      1000|100.0|
# |  3|      1000|100.0|
# |  4|      1000|100.0|
# +---+----------+-----+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

spark = SparkSession.builder.appName("UDF Example").getOrCreate()

data = [("kiệt",), ("tuấn",), ("kiet",)]
df = spark.createDataFrame(data, ["name"])

def to_upper(x):
    return x + 'A'

to_upper_udf = udf(to_upper, StringType())

salaries_df = salaries_df.withColumn("NAME_UPA", to_upper_udf(salaries_df.scores))
salaries_df.show()
# Out:
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+-------+--------+
# |work_year|experience_level|employment_type|           job_title|salary|salary_currency|salary_in_usd|employee_residence|remote_ratio|company_location|company_size|scores|NAME_UP|NAME_UPA|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+-------+--------+
# |     2020|              EN|             FT| Azure Data Engineer|100000|            USD|       100000|                MU|           0|              MU|           S|Values|    MUA| ValuesA|
# |     2020|              EN|             CT|  Staff Data Analyst| 60000|            CAD|        44753|                CA|          50|              CA|           L|Values|    CAA| ValuesA|
# |     2020|              SE|             FT|Staff Data Scientist|164000|            USD|       164000|                US|          50|              US|           M|Values|    USA| ValuesA|
# |     2020|              EN|             FT|        Data Analyst| 42000|            EUR|        47899|                DE|           0|              DE|           L|Values|    DEA| ValuesA|
# |     2020|              EX|             FT|      Data Scientist|300000|            USD|       300000|                US|         100|              US|           L|Values|    USA| ValuesA|
# |     2020|              MI|             CT|  Sales Data Analyst| 60000|            USD|        60000|                NG|           0|              NG|           M|Values|    NGA| ValuesA|
# |     2020|              EX|             FT|  Staff Data Analyst| 15000|            USD|        15000|                NG|           0|              CA|           M|Values|    CAA| ValuesA|
# |     2020|              MI|             FT|Business Data Ana...| 95000|            USD|        95000|                US|           0|              US|           M|Values|    USA| ValuesA|
# |     2020|              EN|             FT|        Data Analyst| 20000|            EUR|        22809|                PT|         100|              PT|           M|Values|    PTA| ValuesA|
# |     2020|              EN|             FT|      Data Scientist| 43200|            EUR|        49268|                DE|           0|              DE|           S|Values|    DEA| ValuesA|
# |     2020|              SE|             FT|Machine Learning ...|157000|            CAD|       117104|                CA|          50|              CA|           L|Values|    CAA| ValuesA|
# |     2020|              EN|             FT|       Data Engineer| 48000|            EUR|        54742|                PK|         100|              DE|           L|Values|    DEA| ValuesA|
# |     2020|              MI|             FT|Product Data Analyst| 20000|            USD|        20000|                HN|           0|              HN|           S|Values|    HNA| ValuesA|
# |     2020|              MI|             FT|       Data Engineer| 51999|            EUR|        59303|                DE|         100|              DE|           S|Values|    DEA| ValuesA|
# |     2020|              EN|             FT|   Big Data Engineer| 70000|            USD|        70000|                US|         100|              US|           L|Values|    USA| ValuesA|
# |     2020|              SE|             FT|      Data Scientist| 60000|            EUR|        68428|                GR|         100|              US|           L|Values|    USA| ValuesA|
# |     2020|              MI|             FT|  Research Scientist|450000|            USD|       450000|                US|           0|              US|           M|Values|    USA| ValuesA|
# |     2020|              MI|             FT|        Data Analyst| 41000|            EUR|        46759|                FR|          50|              FR|           L|Values|    FRA| ValuesA|
# |     2020|              MI|             FT|       Data Engineer| 65000|            EUR|        74130|                AT|          50|              AT|           L|Values|    ATA| ValuesA|
# |     2020|              MI|             FT|      Data Scientist|103000|            USD|       103000|                US|         100|              US|           L|Values|    USA| ValuesA|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+-------+--------+
# only showing top 20 rows

# %%
salaries_df.printSchema()
# Out:
# root
#  |-- work_year: integer (nullable = true)
#  |-- experience_level: string (nullable = true)
#  |-- employment_type: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- salary_currency: string (nullable = true)
#  |-- salary_in_usd: integer (nullable = true)
#  |-- employee_residence: string (nullable = true)
#  |-- remote_ratio: integer (nullable = true)
#  |-- company_location: string (nullable = true)
#  |-- company_size: string (nullable = true)
#  |-- scores: string (nullable = false)
#  |-- NAME_UP: string (nullable = true)

# %%
def plusA(s):
    return s + 'A'
plusA_udf = udf(plusA,StringType())
salaries_df = salaries_df.withColumn("NAME_UPB", plusA_udf(salaries_df['scores']))

# %%
result = salaries_df.filter(salaries_df.salary > 10000).filter(salaries_df.remote_ratio > 70)
result.show()
# Out:
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+-------+--------+--------+
# |work_year|experience_level|employment_type|           job_title|salary|salary_currency|salary_in_usd|employee_residence|remote_ratio|company_location|company_size|scores|NAME_UP|NAME_UPA|NAME_UPB|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+-------+--------+--------+
# |     2020|              EX|             FT|      Data Scientist|300000|            USD|       300000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              EN|             FT|        Data Analyst| 20000|            EUR|        22809|                PT|         100|              PT|           M|Values|    PTA| ValuesA| ValuesA|
# |     2020|              EN|             FT|       Data Engineer| 48000|            EUR|        54742|                PK|         100|              DE|           L|Values|    DEA| ValuesA| ValuesA|
# |     2020|              MI|             FT|       Data Engineer| 51999|            EUR|        59303|                DE|         100|              DE|           S|Values|    DEA| ValuesA| ValuesA|
# |     2020|              EN|             FT|   Big Data Engineer| 70000|            USD|        70000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              SE|             FT|      Data Scientist| 60000|            EUR|        68428|                GR|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|      Data Scientist|103000|            USD|       103000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              EN|             FT|Machine Learning ...|138000|            USD|       138000|                US|         100|              US|           S|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|      Data Scientist| 45760|            USD|        45760|                PH|         100|              US|           S|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|       Data Engineer|106000|            USD|       106000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              EN|             PT|Machine Learning ...| 14000|            EUR|        15966|                DE|         100|              DE|           S|Values|    DEA| ValuesA| ValuesA|
# |     2020|              MI|             FT|      Data Scientist| 60000|            GBP|        76958|                GB|         100|              GB|           S|Values|    GBA| ValuesA| ValuesA|
# |     2020|              SE|             FT|       Data Engineer|188000|            USD|       188000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|      Data Scientist|105000|            USD|       105000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              EN|             FT|        Data Analyst| 91000|            USD|        91000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              EN|             FT|        Data Analyst| 72000|            USD|        72000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              SE|             FT| Lead Data Scientist|190000|            USD|       190000|                US|         100|              US|           S|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|Business Data Ana...|135000|            USD|       135000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|   Lead Data Analyst| 87000|            USD|        87000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# |     2020|              MI|             FT|        Data Analyst| 85000|            USD|        85000|                US|         100|              US|           L|Values|    USA| ValuesA| ValuesA|
# +---------+----------------+---------------+--------------------+------+---------------+-------------+------------------+------------+----------------+------------+------+-------+--------+--------+
# only showing top 20 rows
